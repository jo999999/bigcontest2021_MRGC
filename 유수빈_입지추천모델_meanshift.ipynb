# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os 
os.getcwd()
# Out:
# '/home/jovyan/WIDE_HOME/최종코드'

# %%
b  = pd.read_csv('/home/jovyan/WIDE_HOME/빌딩추천_데이터.csv')  # 먼저 빅밸류 빌딩데이터 불러오기 
b
# Out:
#            주소          경도         위도                        건물 이름      연면적  \
# 0     서초구 반포동  127.017388  37.509633                          NaN  3497.64
# 1     강남구 청담동  127.049984  37.527543                 청담동 111 업무시설  2517.48
# 2     강남구 청담동  127.048451  37.519025                          NaN  4307.51
# 3     강남구 삼성동  127.065719  37.510001                          NaN  9779.89
# 4     강남구 삼성동  127.055382  37.506903                       송암빌딩 Ⅲ  8669.82
# ...       ...         ...        ...                          ...      ...
# 1980  강남구 신사동  127.034510  37.527977                          NaN  2975.11
# 1981  서초구 서초동  127.031360  37.489194                         남강빌딩  9928.85
# 1982  마포구 서교동  126.916238  37.549710                       파피루스빌딩  1579.58
# 1983  서초구 서초동  127.031644  37.488086  서초동 1357-35 업무시설 (우원개발주식회사)  7975.82
# 1984  종로구 통의동  126.972176  37.579322                   국민대학교총동문회관   803.79
#
#       주차장  복합주용도  주변 대규모 점포 수  지하철거리(m)  종합병원거리(m)  대로변거리(m) 자치구명 법정동명  \
# 0       1      0           16    415.54     289.79     28.06  서초구  반포동
# 1       1      0            6    829.36     277.55    123.49  강남구  청담동
# 2       1      0            6    468.15     102.43     55.49  강남구  청담동
# 3       1      0            3    271.72     199.84     34.62  강남구  삼성동
# 4       1      0            4    620.62      76.84     43.53  강남구  삼성동
# ...   ...    ...          ...       ...        ...       ...  ...  ...
# 1980    1      0           11    540.83      90.15     79.09  강남구  신사동
# 1981    1      0            2    569.63     168.14     28.31  서초구  서초동
# 1982    1      0            3    158.90     172.20    126.20  마포구  서교동
# 1983    1      0            1    449.01      98.57     55.76  서초구  서초동
# 1984    0      0            0    412.55     777.03     65.50  종로구  통의동
#
#          평당금액2
# 0     22234158
# 1     16885390
# 2     16885390
# 3     16370755
# 4     16370755
# ...        ...
# 1980  13076419
# 1981  12221723
# 1982   8950356
# 1983  12221723
# 1984  13403172
#
# [1985 rows x 14 columns]

# %%
import pandas as pd
es = pd.read_csv('/home/jovyan/WIDE_HOME/김은선/서울_더존_빅벨류_업종별_동별_경위도.csv') #업종별 동별 경위도 데이터 불러오기 
es.head()
# Out:
#    Unnamed: 0                업종      ADDR    구    동         동도로명       서울시구  \
# 0           0          도매 및 소매업    퇴계로75길   중구  흥인동    흥인동퇴계로75길  서울특별시 중구
# 1           1  전문, 과학 및 기술 서비스업    퇴계로75길   중구  흥인동    흥인동퇴계로75길  서울특별시 중구
# 2           2              부동산업  백제고분로48길  송파구  방이동  방이동백제고분로48길  서울특별시 송파구
# 3           3  전문, 과학 및 기술 서비스업  백제고분로48길  송파구  방이동  방이동백제고분로48길  서울특별시 송파구
# 4           4          도매 및 소매업  백제고분로48길  송파구  방이동  방이동백제고분로48길  서울특별시 송파구
#
#           lon        lat
# 0  127.015582  37.566224
# 1  127.015582  37.566224
# 11210  전문, 과학 및 기술 서비스업   논현로99길  강남구  역삼동   역삼동논현로99길  서울특별시 강남구  127.033026
# 11688  전문, 과학 및 기술 서비스업  언주로107길  강남구  역삼동  역삼동언주로107길  서울특별시 강남구  127.036485
# 11756  전문, 과학 및 기술 서비스업   역삼로52길  강남구  역삼동   역삼동역삼로52길  서울특별시 강남구  127.048042
#
#              lat
# 307    37.497462
# 1046   37.496496
# 1047   37.496496
# 1051   37.496496
# 1054   37.496496
# ...          ...
# 10931  37.505839
# 11116  37.505264
# 11210  37.503258
# 11688  37.507167
# 11756  37.498591
#
# [101 rows x 8 columns]

# %%
building_dong = b[b['법정동명'] =='역삼동']    #빌딩데이터에서 특정 동선택 (클러스터링 결과 기반)
building_dong
# Out:
#            주소          경도         위도                           건물 이름  \
# 14    강남구 역삼동  127.032180  37.499770                     하나금융그룹 강남사옥
# 16    강남구 역삼동  127.037795  37.496504                            영창빌딩
# 35    강남구 역삼동  127.035675  37.499586                           LS 빌딩
# 37    강남구 역삼동  127.045639  37.503161                         메트라이프타워
# 39    강남구 역삼동  127.037173  37.501307                            아주빌딩
# ...       ...         ...        ...                             ...
# 1962  강남구 역삼동  127.035634  37.501637                         역삼현대벤쳐텔
# 1964  강남구 역삼동  127.041823  37.501929                       삼익 라비돌 빌딩
# 1970  강남구 역삼동  127.039612  37.492336                             NaN
# 1973  강남구 역삼동  127.041572  37.496686  오츠카비전빌딩-Otsuka Vision Building
# 1974  강남구 역삼동  127.033070  37.498362                            라인빌딩
#
#            연면적  주차장  복합주용도  주변 대규모 점포 수  지하철거리(m)  종합병원거리(m)  대로변거리(m) 자치구명  \
# 14    24529.68    1      0            4    392.43      52.21     41.86  강남구
# 16     2564.23    1      0            2    477.23     452.95     96.24  강남구
# 35     1999.23    1      0            2    139.65     125.13     89.04  강남구
# 37    18494.91    1      0            2    329.13     310.81     34.13  강남구
# 39    22856.74    1      0            3     93.84     113.38     40.72  강남구
# ...        ...  ...    ...          ...       ...        ...       ...  ...
# 1962  31972.20    1      0            4    130.09      29.77     74.44  강남구
# 1964   7864.08    1      0            1    493.35     291.85     41.76  강남구
# 1970   1265.13    1      0            0    867.90     225.85     34.50  강남구
# 1973   4790.26    1      0            2    631.83     193.24     29.00  강남구
# 1974  11801.42    1      0            4    395.18     170.21    132.27  강남구
#
#      법정동명     평당금액2
# 14    역삼동  13441358
# 16    역삼동  13441358
# 35    역삼동  13441358
# 37    역삼동  13441358
# 39    역삼동  13441358
# ...   ...       ...
# 1962  역삼동  13441358
# 1964  역삼동  13441358
# 1970  역삼동  13441358
# 1973  역삼동  13441358
# 1974  역삼동  13441358
#
# [201 rows x 14 columns]

# %%
comp_dong_x = comp_dong['lat'] # 위도
comp_dong_y = comp_dong['lon'] # 경도


building_dong_x = building_dong['위도']
building_dong_y = building_dong['경도']

# %%
comp_dong_x = list(map(float, comp_dong_x))
comp_dong_y  = list(map(float, comp_dong_y ))

building_dong_x = list(map(float, building_dong_x))
building_dong_y = list(map(float, building_dong_y))

# %%
cmp = pd.concat([pd.DataFrame(comp_dong_x), pd.DataFrame(comp_dong_y )], axis =1) # 업종데이터의 위경도를 합치키
cmp.columns = ['위도', '경도']

buid = pd.concat([pd.DataFrame(building_dong_x), pd.DataFrame(building_dong_y)], axis =1)  # 빌딩데이터의 위경도를 합치기
buid.columns = ['위도', '경도']

# %%
cmp['type'] = 1 # 1은 업종(기업)
buid['type'] = 2 # 2는 빌딩

# %%
all = pd.concat([cmp, buid], axis = 0)  #업종데이터와 빌딩데이터를 합치기
all.reset_index(drop = True, inplace = True)
all
# Out:
#             위도          경도  type
# 0    37.497462  127.032836     1
# 1    37.496496  127.030344     1
# 2    37.496496  127.030344     1
# 3    37.496496  127.030344     1
# 4    37.496496  127.030344     1
# ..         ...         ...   ...
# 297  37.501637  127.035634     2
# 298  37.501929  127.041823     2
# 299  37.492336  127.039612     2
# 300  37.496686  127.041572     2
# 301  37.498362  127.033070     2
#
# [302 rows x 3 columns]

# %%
plt.figure(figsize = (8,8))  # 업종별 지리적 분포와 빌딩의 분포를 시각화 
plt.scatter(all['위도'], all['경도'], c = all['type'])

# %%
import numpy as np

print(type(comp_dong_x))
comp_dong_x= np.array(comp_dong_x)
print(type(comp_dong_x))
gasan_y = np.array(comp_dong_x)
building_dong_x = np.array(building_dong_x)
building_dong_y = np.array(building_dong_y)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ## 회사(업종) 데이터 meanshift로 밀도가 가장 높은 지점을 찾기

# %%
result=[]   #업종데이터에 meanshift를 적용하기 위한 데이터로 변경
for i in range(len(comp_dong_x)):
    result.append([comp_dong_x[i],comp_dong_y[i]])
    
result
# Out:
# [[37.49746176107202, 127.03283568503876],
#  [37.496495759536884, 127.03034415085541],
#  [37.496495759536884, 127.03034415085541],
#  [37.496495759536884, 127.03034415085541],
#  [37.496495759536884, 127.03034415085541],
#  [37.50253633533502, 127.03494323559008],
#  [37.50253633533502, 127.03494323559008],
#  [37.50253633533502, 127.03494323559008],
#  [37.50253633533502, 127.03494323559008],
#  [37.50253633533502, 127.03494323559008],
#  [37.500233748856495, 127.03951586804692],
#  [37.500233748856495, 127.03951586804692],
#  [37.50300072621798, 127.04792820353116],
#  [37.50300072621798, 127.04792820353116],
#  [37.50300072621798, 127.04792820353116],
#  [37.497206584264006, 127.031902561591],
#  [37.497206584264006, 127.031902561591],
#  [37.498028620827604, 127.04171821304271],
#  [37.50035628127746, 127.03046325115645],
#  [37.50035628127746, 127.03046325115645],
#  [37.50035628127746, 127.03046325115645],
#  [37.50035628127746, 127.03046325115645],
#  [37.50035628127746, 127.03046325115645],
#  [37.49847891031956, 127.0346818377867],
#  [37.49847891031956, 127.0346818377867],
#  [37.503136740695794, 127.03898175488979],
#  [37.50181553498612, 127.03408094698973],
#  [37.496482603784706, 127.02948787716588],
#  [37.496482603784706, 127.02948787716588],
#  [37.496482603784706, 127.02948787716588],
#  [37.499737512462296, 127.04136678336614],
#  [37.499737512462296, 127.04136678336614],
# Out:
# bandwidth 값: 0.006

# %%
import numpy as np
from sklearn.cluster import MeanShift

meanshift= MeanShift(bandwidth=0.007)
cluster_labels = meanshift.fit_predict(result)
print('cluster labels 유형:', np.unique(cluster_labels))
# Out:
# cluster labels 유형: [0 1]

# %%
cluster_labels
a=list(cluster_labels)

# %%
from collections import Counter #Counter를 사용하여 각 군집별 얼마나 할당되었는지 확인 
result = Counter(a)
print(result)

result[0]
# Out:
# Counter({0: 71, 1: 30})
# 71

# %%
cls=result.most_common(1)[0][0]  # 가장 할당이 많이 된 클러스터를 cls에 저장 
cls
# Out:
# 0

# %%
meanshift.cluster_centers_  #군집별 중심점 확인
# Out:
# array([[ 37.49730787, 127.03370682],
#        [ 37.50117417, 127.04317184]])

# %%
mil_x=meanshift.cluster_centers_[cls][0]  # cls의 위도 저장
mil_y=meanshift.cluster_centers_[cls][1] #cls의 경도 저장

print(mil_x,mil_y)
# Out:
# 37.49730786988624 127.03370682290372

# %%
only_cmp = all[all['type']==1]  #company(업종인거)
only_cmp
# Out:
#             위도          경도  type
# 0    37.497462  127.032836     1
# 1    37.496496  127.030344     1
# 2    37.496496  127.030344     1
# 3    37.496496  127.030344     1
# 4    37.496496  127.030344     1
# ..         ...         ...   ...
# 96   37.505839  127.035210     1
# 97   37.505264  127.030988     1
# 98   37.503258  127.033026     1
# 99   37.507167  127.036485     1
# 100  37.498591  127.048042     1
#
# [101 rows x 3 columns]

# %%
import matplotlib.pyplot as plt    #업종데이터만 시각화하기 (meanshift를 활용하여 업종위치의 밀도중심 선정한거 시각화)
# %matplotlib inline

only_cmp['meanshift_label']  = cluster_labels
centers = meanshift.cluster_centers_
unique_labels = np.unique(cluster_labels)
markers=['o', 's', '^', 'x', '*']


label_cluster = only_cmp[only_cmp['meanshift_label']==cls]
center_x_y = centers[cls]
# 군집별로 다른 마커로 산점도 적용
plt.scatter(x=only_cmp['위도'], y=only_cmp['경도'], edgecolor='k', marker=markers[cls] )

# 군집별 중심 표현
plt.scatter(x=center_x_y[0], y=center_x_y[1], s=200, color='gray', alpha=0.9, marker=markers[cls])
plt.scatter(x=center_x_y[0], y=center_x_y[1], s=70, color='k', edgecolor='k', marker='$%d$' % cls)

plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
all.loc[len(all)] = [mil_x, mil_y, 3]  #전체데이터에도 업종데이터의 밀도 중심 행 추가
all
# Out:
#             위도          경도  type
# 0    37.497462  127.032836   1.0
# 1    37.496496  127.030344   1.0
# 2    37.496496  127.030344   1.0
# 3    37.496496  127.030344   1.0
# 4    37.496496  127.030344   1.0
# ..         ...         ...   ...
# 298  37.501929  127.041823   2.0
# 299  37.492336  127.039612   2.0
# 300  37.496686  127.041572   2.0
# 301  37.498362  127.033070   2.0
# 302  37.497308  127.033707   3.0
#
# [303 rows x 3 columns]

# %%
plt.scatter(all['위도'], all['경도'], c=all['type'])

# %%
radius = 0.000000001       #업종이 밀집된 밀도중심에서 반경을 넓혀가면서 빌딩을 선택 
flag = 0
result_building_location = {"x":[],"y":[], "i":[], "dist":[]}

while True:
    for i in range(0, len(building_dong_x)):
        distance = np.sqrt((building_dong_x[i] - mil_x) ** 2 + (building_dong_y[i] - mil_y) ** 2)
        #print('dis', distance)
        #print('radi', radius)
        if distance <= radius:
            if i in result_building_location['i']:
                continue
            print('ok')
            print(i,'번째', building_dong_x[i], building_dong_y[i])
            result_building_location['x'].append(building_dong_x[i])
            result_building_location['y'].append(building_dong_y[i])
            result_building_location['i'].append(i)
            result_building_location['dist'].append(distance)
            flag += 1
    if flag >= 4:
        break
    else:
        radius += 0.0002
        print('현재 radius', radius)
# Out:
# 현재 radius 0.000200001
# 현재 radius 0.000400001
# 현재 radius 0.000600001
# 현재 radius 0.0008000009999999999
# 현재 radius 0.001000001
# 현재 radius 0.001200001
# 현재 radius 0.0014000010000000001
# ok
# 54 번째 37.498428689677326 127.03417676182087
# ok
# 58 번째 37.497774411911756 127.03246730462202
# ok
# 88 번째 37.49866635475012 127.03372130456732
# ok
# 91 번째 37.49855052890335 127.03377688335331
# ok
# 136 번째 37.49821865841882 127.03270470523294
# ok
# 182 번째 37.49633535086007 127.0326998404352
# ok
# 186 번째 37.49855884482057 127.03411416280977
# ok
# 200 번째 37.498362406315366 127.0330702937262

# %%
result_building_location  #선정된 빌딩의 위도,경도,밀도중심에서의 거리
# Out:
# {'x': [37.498428689677326,
#   37.497774411911756,
#   37.49866635475012,
#   37.49855052890335,
#   37.49821865841882,
#   37.49633535086007,
#   37.49855884482057,
#   37.498362406315366],
#  'y': [127.03417676182087,
#   127.03246730462202,
#   127.03372130456732,
#   127.03377688335331,
#   127.03270470523294,
#   127.0326998404352,
#   127.03411416280977,
#   127.0330702937262],
#  'i': [54, 58, 88, 91, 136, 182, 186, 200],
#  'dist': [0.0012153516322181228,
#   0.0013244119571557238,
#   0.0013585620500984681,
#   0.0012446324354596998,
#   0.0013541697002835058,
#   0.0013999310512233922,
#   0.0013156230787650664,
#   0.0012317534145237351]}

# %%
cmp['type'] = 'comp'

buid['type'] = 'building'
buid.loc[result_building_location['i'], 'type'] = 'here!'

# %%
candidates = buid[buid['type'] == 'here!']
candidates['dist'] = result_building_location['dist']
candidates = candidates.sort_values('dist', ascending=True)
candidates
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             위도          경도   type      dist
# 54   37.498429  127.034177  here!  0.001215
# 200  37.498362  127.033070  here!  0.001232
# 91   37.498551  127.033777  here!  0.001245
# 186  37.498559  127.034114  here!  0.001316
# 58   37.497774  127.032467  here!  0.001324
# 136  37.498219  127.032705  here!  0.001354
# 88   37.498666  127.033721  here!  0.001359
# 182  37.496335  127.032700  here!  0.001400

# %%
all = pd.concat([cmp, buid], axis=0)   #업종(comp)데이터와 빌딩데이터(building), 추천후보 빌딩데이터(here!)를 합친다.
all.reset_index(drop=True, inplace=True)
all.loc[len(all)] = [mil_x, mil_y, 'mildo_center']
all
# Out:
#             위도          경도          type
# 0    37.497462  127.032836          comp
# 1    37.496496  127.030344          comp
# 2    37.496496  127.030344          comp
# 3    37.496496  127.030344          comp
# 4    37.496496  127.030344          comp
# ..         ...         ...           ...
# 298  37.501929  127.041823      building
# 299  37.492336  127.039612      building
# 300  37.496686  127.041572      building
# 301  37.498362  127.033070         here!
# 302  37.497308  127.033707  mildo_center
#
# [303 rows x 3 columns]

# %%
import seaborn as sns
plt.figure(figsize = (10,10))
g =sns.scatterplot(x="위도", y="경도",
              hue="type",
              data=all)

g.set(xscale="log")
# Out:
# /home/jovyan/.local/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# [None]
# /home/jovyan/.local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50948 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/jovyan/.local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/jovyan/.local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50948 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/jovyan/.local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/jovyan/.local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/jovyan/.local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 선정된 곳 보여주기

# %%
candidates
# Out:
#             위도          경도   type      dist
# 54   37.498429  127.034177  here!  0.001215
# 200  37.498362  127.033070  here!  0.001232
# 91   37.498551  127.033777  here!  0.001245
# 186  37.498559  127.034114  here!  0.001316
# 58   37.497774  127.032467  here!  0.001324
# 136  37.498219  127.032705  here!  0.001354
# 88   37.498666  127.033721  here!  0.001359
# 182  37.496335  127.032700  here!  0.001400

# %%
dist = candidates['dist'].values
dist
# Out:
# array([0.00121535, 0.00123175, 0.00124463, 0.00131562, 0.00132441,
#        0.00135417, 0.00135856, 0.00139993])

# %%
here_idx=[]
for i in range(len(candidates)):
    a=b[b['위도']==candidates['위도'].iloc[i]]
    here_idx.append(a[a['경도']==candidates['경도'].iloc[i]].index)


here_idx  ## 선정된 곳의 인덱스 추출
# Out:
# [Int64Index([592], dtype='int64'),
#  Int64Index([1974], dtype='int64'),
#  Int64Index([934], dtype='int64'),
#  Int64Index([1870], dtype='int64'),
#  Int64Index([622], dtype='int64'),
#  Int64Index([1387], dtype='int64'),
#  Int64Index([907], dtype='int64'),
#  Int64Index([1801], dtype='int64')]

# %%
k = np.array(here_idx)

idx=[]
for i in k:
    idx.append(i[0])
    
idx
# Out:
# [592, 1974, 934, 1870, 622, 1387, 907, 1801]

# %%
here_building = b.iloc[idx]   #기존 빌딩데이터에서 선정된곳을 here_building으로 저장
here_building
# Out:
#            주소          경도         위도     건물 이름       연면적  주차장  복합주용도  \
# 592   강남구 역삼동  127.034177  37.498429     제니스빌딩   1999.40    1      0
# 1974  강남구 역삼동  127.033070  37.498362      라인빌딩  11801.42    1      0
# 934   강남구 역삼동  127.033777  37.498551       NaN   1996.38    1      0
# 1870  강남구 역삼동  127.034114  37.498559   산하LAW타워   1999.56    1      0
# 622   강남구 역삼동  127.032467  37.497774    823 빌딩  14233.49    1      0
# 1387  강남구 역삼동  127.032705  37.498219       NaN   1267.14    1      0
# 907   강남구 역삼동  127.033721  37.498666  다원디자인 빌딩   1996.38    1      0
# 1801  강남구 역삼동  127.032700  37.496335       NaN   4844.72    0      0
#
#       주변 대규모 점포 수  지하철거리(m)  종합병원거리(m)  대로변거리(m) 자치구명 법정동명     평당금액2
# 592             3    321.22     126.66    161.48  강남구  역삼동  13441358
# 1974            4    395.18     170.21    132.27  강남구  역삼동  13441358
# 934             3    335.00     120.74    135.87  강남구  역삼동  13441358
# 1870            2    313.80     112.74    146.01  강남구  역삼동  13441358
# 622             4    394.43     232.12    173.68  강남구  역삼동  13441358
# 1387            4    416.14     196.05    135.38  강남구  역삼동  13441358
# 907             4    329.70     110.83    122.11  강남구  역삼동  13441358
# 1801            3    402.06     384.39    256.97  강남구  역삼동  13441358

# %%
here_building['dist']=dist  #밀도중심에서 얼마나 떨어져 있는지 dist컬럼으로 저장
here_building
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#
# %% [markdown]
# 편의성 지수를 계산하기위해 지하철거리, 종합병원거리, 주변 대규모 점포 수, dist 컬럼에 standartscaler적용

# %%
from sklearn.preprocessing import StandardScaler

# 객체생성
scaler = StandardScaler()

A_n = scaler.fit_transform(here_building['지하철거리(m)'].values.reshape(-1,1))
here_building.insert(0, '지하철거리_scaled', A_n)

scaler = StandardScaler()
A_n = scaler.fit_transform(here_building['종합병원거리(m)'].values.reshape(-1,1))
here_building.insert(0, '종합병원거리_scaled', A_n)

scaler = StandardScaler()
A_n = scaler.fit_transform(here_building['대로변거리(m)'].values.reshape(-1,1))
here_building.insert(0, '대로변거리_scaled', A_n)

scaler = StandardScaler()
A_n = scaler.fit_transform(here_building['주변 대규모 점포 수'].values.reshape(-1,1))
here_building.insert(0, '대규모점포수_scaled', A_n)

scaler = StandardScaler()
A_n = scaler.fit_transform(here_building['dist'].values.reshape(-1,1))
here_building.insert(0, 'dist_scaled', A_n)
# df.drop(['A'], axis=1, inplace=True)

# %%
here_building
# Out:
#       dist_scaled  대규모점포수_scaled  대로변거리_scaled  종합병원거리_scaled  지하철거리_scaled  \
# 592     -1.429994      -0.538816      0.086549      -0.633185     -1.071105
# 1974    -1.169975       0.898027     -0.633963      -0.132341      0.805176
# 934     -0.965803      -0.538816     -0.545164      -0.701268     -0.721522
# 1870     0.159620      -1.975658     -0.295044      -0.793271     -1.259342
# 622      0.298951       0.898027      0.387482       0.579651      0.786149
# 1387     0.770703       0.898027     -0.557250       0.164830      1.336907
# 907      0.840336       0.898027     -0.884576      -0.815237     -0.855977
# 1801     1.496163      -0.538816      2.441966       2.330822      0.979714
#
#            주소          경도         위도     건물 이름  주변 대규모 점포 수  지하철거리(m)  \
# 592   강남구 역삼동  127.034177  37.498429     제니스빌딩            3    321.22
# 1974  강남구 역삼동  127.033070  37.498362      라인빌딩            4    395.18
# 934   강남구 역삼동  127.033777  37.498551       NaN            3    335.00
# 1870  강남구 역삼동  127.034114  37.498559   산하LAW타워            2    313.80
# 622   강남구 역삼동  127.032467  37.497774    823 빌딩            4    394.43
# 1387  강남구 역삼동  127.032705  37.498219       NaN            4    416.14
# 907   강남구 역삼동  127.033721  37.498666  다원디자인 빌딩            4    329.70
# 1801  강남구 역삼동  127.032700  37.496335       NaN            3    402.06
#
#       종합병원거리(m)  대로변거리(m) 자치구명 법정동명      dist
# 592      126.66    161.48  강남구  역삼동  0.001215
# 1974     170.21    132.27  강남구  역삼동  0.001232
# 934      120.74    135.87  강남구  역삼동  0.001245
# 1870     112.74    146.01  강남구  역삼동  0.001316
# 622      232.12    173.68  강남구  역삼동  0.001324
# 1387     196.05    135.38  강남구  역삼동  0.001354
# 907      110.83    122.11  강남구  역삼동  0.001359
# 1801     384.39    256.97  강남구  역삼동  0.001400

# %%
here_building['편의성']= here_building['대로변거리_scaled']+here_building['종합병원거리_scaled']+here_building['지하철거리_scaled']-here_building['대규모점포수_scaled']
here_building  #편의성 지표생성
# Out:
